# %%
from utils.show import write_video 
from aitviewer.headless import HeadlessRenderer
from utils.defaults import DEFAULTS
from pathlib import Path

# Careful!: creating more that one renderer in a single session causes an error
renderer = HeadlessRenderer()
# Out:
# c:\Users\janr\Documents\MagCode\.venv_py310\lib\site-packages\Pythonwin

# %%
out_path = Path(DEFAULTS.data_root) / 'temp' / 'output_m.pkl'
out_video = Path(DEFAULTS.data_root) / 'temp' / 'output_m.mp4'
write_video(out_path, out_video, renderer)
# Out:
# Rendering frames: 100%|██████████| 404/404 [00:18<00:00, 21.90it/s]
# Video saved to D:\ClothSim\ccraft_data\temp\output_m.mp4
